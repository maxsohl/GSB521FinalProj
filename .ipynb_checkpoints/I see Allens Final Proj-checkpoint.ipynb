# %%
pip install folium

# %%
pip install folium --upgrade

# %%
pip install uszipcode

# %%
import pandas as pd
import io
import datetime
from urllib.request import urlopen
import matplotlib.pyplot as plt
import plotly.express as px
from urllib import request
import json
import warnings
import numpy as np
import seaborn as sns
import uszipcode
from uszipcode import SearchEngine
import folium
from folium.plugins import HeatMap
# Out:
# /Users/max/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
url = 'https://raw.githubusercontent.com/maxsohl/GSB521FinalProj/main/ufo_sightings_scrubbed.csv'
warnings.filterwarnings('ignore')
df = pd.read_csv(url)

# %%
us_df = df.loc[df["country"] == "us"]

# %%
us_df['datetime'] = pd.to_datetime(us_df['datetime']) #convert to datetime data type
us_df['date'] = us_df['datetime'].dt.date #seperate into two columns
us_df['time'] = us_df['datetime'].dt.time
pd.to_datetime(us_df['date'])
us_df['year'] = us_df['date'].apply(lambda x: x.strftime('%Y'))
us_df['year'] = us_df['year'].astype(int)
year_to_filter = 2000
us_df_2000 = us_df[us_df['year'] > year_to_filter]
us_df_2000
# Out:
#                  datetime           city state country      shape  \
# 102   2001-10-10 03:00:00  rockwell city    ia      us   triangle
# 105   2001-10-10 20:35:00        hayward    ca      us     circle
# 106   2001-10-10 21:15:00        ottumwa    ia      us  rectangle
# 107   2001-10-10 21:30:00         fresno    ca      us   changing
# 108   2001-10-10 22:00:00        phoenix    az      us   triangle
# ...                   ...            ...   ...     ...        ...
# 80327 2013-09-09 21:15:00      nashville    tn      us      light
# 80328 2013-09-09 22:00:00          boise    id      us     circle
# 80329 2013-09-09 22:00:00           napa    ca      us      other
# 80330 2013-09-09 22:20:00         vienna    va      us     circle
# 80331 2013-09-09 23:00:00         edmond    ok      us      cigar
#
#       duration (seconds) duration (hours/min)  \
# 102                  240              4 min.s
# 105                  120               2/min.
# 106                  300          3-5 minutes
# 107                  900        15 min. apprx
# 108                   60   less then a minute
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 102    Large&#44silent&#44slow&#44low to the ground d...  2002-07-01
# 105    FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...  2001-11-20
# 106    We saw a square object at night&#44  which had...  2001-11-20
# 107    Objects were sighted driving north on Highway ...  2001-11-20
# 108    Triangle shaped craft spotted flying west to e...  2001-11-20
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...  2013-09-30
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 80329                                       Napa UFO&#44  2013-09-30
# 80330  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#          latitude  longitude         date      time  year
# 102    42.3952778  -94.633611  2001-10-10  03:00:00  2001
# 105    37.6688889 -122.079722  2001-10-10  20:35:00  2001
# 106    41.0041667  -92.373611  2001-10-10  21:15:00  2001
# 107    36.7477778 -119.771389  2001-10-10  21:30:00  2001
# 108    33.4483333 -112.073333  2001-10-10  22:00:00  2001
# ...           ...         ...         ...       ...   ...
# 80327   36.165833  -86.784444  2013-09-09  21:15:00  2013
# 80328   43.613611 -116.202500  2013-09-09  22:00:00  2013
# 80329   38.297222 -122.284444  2013-09-09  22:00:00  2013
# 80330   38.901111  -77.265556  2013-09-09  22:20:00  2013
# 80331   35.652778  -97.477778  2013-09-09  23:00:00  2013
#
# [50629 rows x 14 columns]

# %% [markdown]
# ### Import county dataset and merge with alien data

# %% [markdown]
# source: https://public.opendatasoft.com/explore/dataset/geonames-all-cities-with-a-population-1000/table/?disjunctive.cou_name_en&sort=name

# %%
url = 'https://raw.githubusercontent.com/maxsohl/GSB521FinalProj/main/city_county.csv'
city_county = pd.read_csv(url)
city_county
# Out:
#       state                       city          county
# 0        ak                       adak  aleutians west
# 1        ak                   akiachak          bethel
# 2        ak                      akiak          bethel
# 3        ak                     akutan  aleutians east
# 4        ak                   alakanuk        kusilvak
# ...     ...                        ...             ...
# 29875    wy                    worland        washakie
# 29876    wy                     wright        campbell
# 29877    wy                     wyarno        sheridan
# 29878    wy  yellowstone national park            park
# 29879    wy                      yoder          goshen
#
# [29880 rows x 3 columns]

# %%
merged_df = pd.merge(us_df_2000, city_county, on= ['city','state'], how = 'left')
merged_df.dropna(subset=['county'], inplace=True)
merged_df
# Out:
#                  datetime           city state country      shape  \
# 0     2001-10-10 03:00:00  rockwell city    ia      us   triangle
# 1     2001-10-10 20:35:00        hayward    ca      us     circle
# 2     2001-10-10 21:15:00        ottumwa    ia      us  rectangle
# 3     2001-10-10 21:30:00         fresno    ca      us   changing
# 4     2001-10-10 22:00:00        phoenix    az      us   triangle
# ...                   ...            ...   ...     ...        ...
# 55912 2013-09-09 21:15:00      nashville    tn      us      light
# 55914 2013-09-09 22:00:00          boise    id      us     circle
# 55915 2013-09-09 22:00:00           napa    ca      us      other
# 55916 2013-09-09 22:20:00         vienna    va      us     circle
# 55917 2013-09-09 23:00:00         edmond    ok      us      cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                    240              4 min.s
# 1                    120               2/min.
# 2                    300          3-5 minutes
# 3                    900        15 min. apprx
# 4                     60   less then a minute
# ...                  ...                  ...
# 55912              600.0           10 minutes
# 55914             1200.0           20 minutes
# 55915             1200.0                 hour
# 55916                5.0            5 seconds
# 55917             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      Large&#44silent&#44slow&#44low to the ground d...  2002-07-01
# 1      FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...  2001-11-20
# 2      We saw a square object at night&#44  which had...  2001-11-20
# 3      Objects were sighted driving north on Highway ...  2001-11-20
# 4      Triangle shaped craft spotted flying west to e...  2001-11-20
# ...                                                  ...         ...
# 55912  Round from the distance/slowly changing colors...  2013-09-30
# 55914  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 55915                                       Napa UFO&#44  2013-09-30
# 55916  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 55917  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#          latitude  longitude         date      time  year    county
# 0      42.3952778  -94.633611  2001-10-10  03:00:00  2001   calhoun
# 1      37.6688889 -122.079722  2001-10-10  20:35:00  2001   alameda
# 2      41.0041667  -92.373611  2001-10-10  21:15:00  2001   wapello
# 3      36.7477778 -119.771389  2001-10-10  21:30:00  2001    fresno
# 4      33.4483333 -112.073333  2001-10-10  22:00:00  2001  maricopa
# ...           ...         ...         ...       ...   ...       ...
# 55912   36.165833  -86.784444  2013-09-09  21:15:00  2013  davidson
# 55914   43.613611 -116.202500  2013-09-09  22:00:00  2013       ada
# 55915   38.297222 -122.284444  2013-09-09  22:00:00  2013      napa
# 55916   38.901111  -77.265556  2013-09-09  22:20:00  2013   fairfax
# 55917   35.652778  -97.477778  2013-09-09  23:00:00  2013  oklahoma
#
# [50858 rows x 15 columns]

# %% [markdown]
# ### Import EducationByCounty and merge with df

# %%
url = 'https://raw.githubusercontent.com/maxsohl/GSB521FinalProj/main/EducationByCounty.csv'
education = pd.read_csv(url)

# %%
education['state'] = education['State'].str.lower()
education['county'] = education['Area name'].str.lower()

# %%
#to match merged_df with education add county after every county name in merged_df
def add_county(word):
    return f"{word} county"

merged_df['county'] = merged_df['county'].apply(add_county)

# %%
education_merged_df = pd.merge(merged_df, education, on= ['county','state'], how = 'left')

# %%
education_merged_df
# Out:
#                  datetime           city state country      shape  \
# 0     2001-10-10 03:00:00  rockwell city    ia      us   triangle
# 1     2001-10-10 20:35:00        hayward    ca      us     circle
# 2     2001-10-10 21:15:00        ottumwa    ia      us  rectangle
# 3     2001-10-10 21:30:00         fresno    ca      us   changing
# 4     2001-10-10 22:00:00        phoenix    az      us   triangle
# ...                   ...            ...   ...     ...        ...
# 50853 2013-09-09 21:15:00      nashville    tn      us      light
# 50854 2013-09-09 22:00:00          boise    id      us     circle
# 50855 2013-09-09 22:00:00           napa    ca      us      other
# 50856 2013-09-09 22:20:00         vienna    va      us     circle
# 50857 2013-09-09 23:00:00         edmond    ok      us      cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                    240              4 min.s
# 1                    120               2/min.
# 2                    300          3-5 minutes
# 3                    900        15 min. apprx
# 4                     60   less then a minute
# ...                  ...                  ...
# 50853              600.0           10 minutes
# 50854             1200.0           20 minutes
# 50855             1200.0                 hour
# 50856                5.0            5 seconds
# 50857             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      Large&#44silent&#44slow&#44low to the ground d...  2002-07-01
# 1      FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...  2001-11-20
# 2      We saw a square object at night&#44  which had...  2001-11-20
# 3      Objects were sighted driving north on Highway ...  2001-11-20
# 4      Triangle shaped craft spotted flying west to e...  2001-11-20
# ...                                                  ...         ...
# 50853  Round from the distance/slowly changing colors...  2013-09-30
# 50854  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 50855                                       Napa UFO&#44  2013-09-30
# 50856  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 50857  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#          latitude  ...  \
# 0      42.3952778  ...
# 1      37.6688889  ...
# 2      41.0041667  ...
# 3      36.7477778  ...
# 4      33.4483333  ...
# ...           ...  ...
# 50853   36.165833  ...
# 50854   43.613611  ...
# 50855   38.297222  ...
# 50856   38.901111  ...
# 50857   35.652778  ...
#
#        Percent of adults completing some college or associate's degree, 2008-12  \
# 0                                                   34.5
# 1                                                   25.6
# 2                                                   31.0
# 3                                                   30.7
# 4                                                   33.5
# ...                                                  ...
# 50853                                               26.3
# 50854                                               36.2
# 50855                                               32.0
# 50856                                               20.1
# 50857                                               31.1
#
#       Percent of adults with a bachelor's degree or higher, 2008-12  \
# 0                                                   19.1
# 1                                                   41.1
# 2                                                   15.4
# 3                                                   19.4
# 4                                                   29.5
# ...                                                  ...
# 50853                                               35.0
# 50854                                               35.3
# 50855                                               31.2
# 50856                                               58.2
# 50857                                               29.3
#
#       Less than a high school diploma, 2017-21  \
# 0                                          423
# 1                                      131,272
# 2                                        2,885
# 3                                      136,835
# 4                                      326,737
# ...                                        ...
# 50853                                   48,693
# 50854                                   16,433
# 50855                                   14,541
# 50856                                   51,874
# 50857                                   59,864
#
#        High school diploma only, 2017-21  \
# 0                                  2,695
# 1                                198,825
# 2                                  8,786
# 3                                140,532
# 4                                644,940
# ...                                  ...
# 50853                            104,797
# 50854                             68,936
# 50855                             17,698
# 50856                             96,148
# 50857                            127,327
#
#       Some college or associate's degree, 2017-21  \
# 0                                           2,458
# 1                                         271,096
# 2                                           7,765
# 3                                         201,826
# 4                                         950,635
# ...                                           ...
# 50853                                     120,227
# 50854                                     110,566
# 50855                                      29,842
# 50856                                     137,108
# 50857                                     155,471
#
#        Bachelor's degree or higher, 2017-21  \
# 0                                     1,477
# 1                                   592,670
# 2                                     4,586
# 3                                   140,183
# 4                                 1,006,096
# ...                                     ...
# 50853                               218,762
# 50854                               134,694
# 50855                                36,464
# 50856                               496,667
# 50857                               174,202
#
#       Percent of adults with less than a high school diploma, 2017-21  \
# 0                                                    6.0
# 1                                                   11.0
# 2                                                   12.0
# 3                                                   22.1
# 4                                                   11.2
# ...                                                  ...
# 50853                                                9.9
# 50854                                                5.0
# 50855                                               14.8
# 50856                                                6.6
# 50857                                               11.6
#
#       Percent of adults with a high school diploma only, 2017-21  \
# 0                                                   38.2
# 1                                                   16.7
# 2                                                   36.6
# 3                                                   22.7
# 4                                                   22.0
# ...                                                  ...
# 50853                                               21.3
# 50854                                               20.8
# 50855                                               18.0
# 50856                                               12.3
# 50857                                               24.6
#
#        Percent of adults completing some college or associate's degree, 2017-21  \
# 0                                                   34.9
# 1                                                   22.7
# 2                                                   32.3
# 3                                                   32.6
# 4                                                   32.5
# ...                                                  ...
# 50853                                               24.4
# 50854                                               33.4
# 50855                                               30.3
# 50856                                               17.5
# 50857                                               30.1
#
#        Percent of adults with a bachelor's degree or higher, 2017-21
# 0                                                   20.9
# 1                                                   49.6
# 2                                                   19.1
# 3                                                   22.6
# 4                                                   34.4
# ...                                                  ...
# 50853                                               44.4
# 50854                                               40.7
# 50855                                               37.0
# 50856                                               63.5
# 50857                                               33.7
#
# [50858 rows x 70 columns]

# %%
print(education_merged_df.columns)
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude ', 'date', 'time', 'year', 'county',
#        'Federal Information Processing Standard (FIPS) Code', 'State',
#        'Area name', '2003 Rural-urban Continuum Code',
#        '2003 Urban Influence Code', '2013 Rural-urban Continuum Code',
#        '2013 Urban Influence Code', 'Less than a high school diploma, 1970',
#        'High school diploma only, 1970', 'Some college (1-3 years), 1970',
#        'Four years of college or higher, 1970',
#        'Percent of adults with less than a high school diploma, 1970',
#        'Percent of adults with a high school diploma only, 1970',
#        'Percent of adults completing some college (1-3 years), 1970',
#        'Percent of adults completing four years of college or higher, 1970',
#        'Less than a high school diploma, 1980',
#        'High school diploma only, 1980', 'Some college (1-3 years), 1980',
#        'Four years of college or higher, 1980',
#        'Percent of adults with less than a high school diploma, 1980',
#        'Percent of adults with a high school diploma only, 1980',
#        'Percent of adults completing some college (1-3 years), 1980',
#        'Percent of adults completing four years of college or higher, 1980',
#        'Less than a high school diploma, 1990',
#        'High school diploma only, 1990',
#        'Some college or associate's degree, 1990',
#        'Bachelor's degree or higher, 1990',
#        'Percent of adults with less than a high school diploma, 1990',
#        'Percent of adults with a high school diploma only, 1990',
#        'Percent of adults completing some college or associate's degree, 1990',
#        'Percent of adults with a bachelor's degree or higher, 1990',
#        'Less than a high school diploma, 2000',
#        'High school diploma only, 2000',
#        'Some college or associate's degree, 2000',
#        'Bachelor's degree or higher, 2000',
#        'Percent of adults with less than a high school diploma, 2000',
#        'Percent of adults with a high school diploma only, 2000',
#        'Percent of adults completing some college or associate's degree, 2000',
#        'Percent of adults with a bachelor's degree or higher, 2000',
#        'Less than a high school diploma, 2008-12',
#        'High school diploma only, 2008-12',
#        'Some college or associate's degree, 2008-12',
#        'Bachelor's degree or higher, 2008-12',
#        'Percent of adults with less than a high school diploma, 2008-12',
#        'Percent of adults with a high school diploma only, 2008-12',
#        'Percent of adults completing some college or associate's degree, 2008-12',
#        'Percent of adults with a bachelor's degree or higher, 2008-12',
#        'Less than a high school diploma, 2017-21',
#        'High school diploma only, 2017-21',
#        'Some college or associate's degree, 2017-21',
#        'Bachelor's degree or higher, 2017-21',
#        'Percent of adults with less than a high school diploma, 2017-21',
#        'Percent of adults with a high school diploma only, 2017-21',
#        'Percent of adults completing some college or associate's degree, 2017-21',
#        'Percent of adults with a bachelor's degree or higher, 2017-21'],
#       dtype='object')

# %% [markdown]
# ## Bring in fips number/ merge with educ data

# %%
url = 'https://raw.githubusercontent.com/maxsohl/GSB521FinalProj/main/fips2county.csv'
fips_to_county = pd.read_csv(url)
fips_to_county['county'] = fips_to_county['CountyName']
fips_to_county['state'] = fips_to_county['StateAbbr']
fips_to_county['fips'] = fips_to_county['CountyFIPS']
fips_to_county = fips_to_county.loc[:, ['county', 'state','fips']]
fips_to_county
# Out:
#           county state   fips
# 0        Autauga    AL   1001
# 1        Baldwin    AL   1003
# 2        Barbour    AL   1005
# 3           Bibb    AL   1007
# 4         Blount    AL   1009
# ...          ...   ...    ...
# 3138  Sweetwater    WY  56037
# 3139       Teton    WY  56039
# 3140       Uinta    WY  56041
# 3141    Washakie    WY  56043
# 3142      Weston    WY  56045
#
# [3143 rows x 3 columns]

# %% [markdown]
# ### Merge fips_to_county with education_merged_df so can merge pop on fips

# %%
#Clean fips_to_county so it can be merged with education_merged_df
fips_to_county['county'] = fips_to_county['county'].str.lower()
fips_to_county['state'] = fips_to_county['state'].str.lower()
fips_to_county
# Out:
#           county state   fips
# 0        autauga    al   1001
# 1        baldwin    al   1003
# 2        barbour    al   1005
# 3           bibb    al   1007
# 4         blount    al   1009
# ...          ...   ...    ...
# 3138  sweetwater    wy  56037
# 3139       teton    wy  56039
# 3140       uinta    wy  56041
# 3141    washakie    wy  56043
# 3142      weston    wy  56045
#
# [3143 rows x 3 columns]

# %%
def add_county(word):
    return f"{word} county"

fips_to_county['county'] = fips_to_county['county'].apply(add_county)


fips_to_county
# Out:
#                  county state   fips
# 0        autauga county    al   1001
# 1        baldwin county    al   1003
# 2        barbour county    al   1005
# 3           bibb county    al   1007
# 4         blount county    al   1009
# ...                 ...   ...    ...
# 3138  sweetwater county    wy  56037
# 3139       teton county    wy  56039
# 3140       uinta county    wy  56041
# 3141    washakie county    wy  56043
# 3142      weston county    wy  56045
#
# [3143 rows x 3 columns]

# %%
#Merge fips and educ
education_merged_df_fips = pd.merge(education_merged_df, fips_to_county, on=['county','state'], how='left')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 100)

# %%
#convert education_merged_df_fips['fips'] from float to int
education_merged_df_fips = education_merged_df_fips.dropna(subset=['fips'])
education_merged_df_fips['fips'] = education_merged_df_fips['fips'].astype(int)
education_merged_df_fips
# Out:
#                  datetime           city state country      shape duration (seconds)  \
# 0     2001-10-10 03:00:00  rockwell city    ia      us   triangle                240
# 1     2001-10-10 20:35:00        hayward    ca      us     circle                120
# 2     2001-10-10 21:15:00        ottumwa    ia      us  rectangle                300
# 3     2001-10-10 21:30:00         fresno    ca      us   changing                900
# 4     2001-10-10 22:00:00        phoenix    az      us   triangle                 60
# ...                   ...            ...   ...     ...        ...                ...
# 50853 2013-09-09 21:15:00      nashville    tn      us      light              600.0
# 50854 2013-09-09 22:00:00          boise    id      us     circle             1200.0
# 50855 2013-09-09 22:00:00           napa    ca      us      other             1200.0
# 50856 2013-09-09 22:20:00         vienna    va      us     circle                5.0
# 50857 2013-09-09 23:00:00         edmond    ok      us      cigar             1020.0
#
#       duration (hours/min)                                           comments date posted  \
# 0                  4 min.s  Large&#44silent&#44slow&#44low to the ground d...  2002-07-01
# 1                   2/min.  FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...  2001-11-20
# 2              3-5 minutes  We saw a square object at night&#44  which had...  2001-11-20
# 3            15 min. apprx  Objects were sighted driving north on Highway ...  2001-11-20
# 4       less then a minute  Triangle shaped craft spotted flying west to e...  2001-11-20
# ...                    ...                                                ...         ...
# 50853           10 minutes  Round from the distance/slowly changing colors...  2013-09-30
# 50854           20 minutes  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 50855                 hour                                       Napa UFO&#44  2013-09-30
# 50856            5 seconds  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 50857           17 minutes  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#          latitude  longitude         date      time  year           county  \
# 0      42.3952778  -94.633611  2001-10-10  03:00:00  2001   calhoun county
# 1      37.6688889 -122.079722  2001-10-10  20:35:00  2001   alameda county
# 2      41.0041667  -92.373611  2001-10-10  21:15:00  2001   wapello county
# 3      36.7477778 -119.771389  2001-10-10  21:30:00  2001    fresno county
# 4      33.4483333 -112.073333  2001-10-10  22:00:00  2001  maricopa county
# ...           ...         ...         ...       ...   ...              ...
# 50853   36.165833  -86.784444  2013-09-09  21:15:00  2013  davidson county
# 50854   43.613611 -116.202500  2013-09-09  22:00:00  2013       ada county
# 50855   38.297222 -122.284444  2013-09-09  22:00:00  2013      napa county
# 50856   38.901111  -77.265556  2013-09-09  22:20:00  2013   fairfax county
# 50857   35.652778  -97.477778  2013-09-09  23:00:00  2013  oklahoma county
#
#        Federal Information Processing Standard (FIPS) Code State        Area name  \
# 0                                                19025.0      IA   Calhoun County
# 1                                                 6001.0      CA   Alameda County
# 2                                                19179.0      IA   Wapello County
# 3                                                 6019.0      CA    Fresno County
# 4                                                 4013.0      AZ  Maricopa County
# ...                                                  ...     ...              ...
# 50853                                            47037.0      TN  Davidson County
# 50854                                            16001.0      ID       Ada County
# 50855                                             6055.0      CA      Napa County
# 50856                                            51059.0      VA   Fairfax County
# 50857                                            40109.0      OK  Oklahoma County
#
#        2003 Rural-urban Continuum Code  2003 Urban Influence Code  \
# 0                                  9.0                       10.0
# 1                                  1.0                        1.0
# 2                                  5.0                        8.0
# 3                                  2.0                        2.0
# 4                                  1.0                        1.0
# ...                                ...                        ...
# 50853                              1.0                        1.0
# 50854                              2.0                        2.0
# 50855                              3.0                        2.0
# 50856                              1.0                        1.0
# 50857                              1.0                        1.0
#
#        2013 Rural-urban Continuum Code  2013 Urban Influence Code  \
# 0                                  9.0                       10.0
# 1                                  1.0                        1.0
# 2                                  5.0                        8.0
# 3                                  2.0                        2.0
# 4                                  1.0                        1.0
# ...                                ...                        ...
# 50853                              1.0                        1.0
# 50854                              2.0                        2.0
# 50855                              3.0                        2.0
# 50856                              1.0                        1.0
# 50857                              1.0                        1.0
#
#       Less than a high school diploma, 1970 High school diploma only, 1970  \
# 0                                     3,740                          3,319
# 1                                   217,589                        197,371
# 2                                    12,247                          8,893
# 3                                   100,900                         59,798
# 4                                   203,922                        164,605
# ...                                     ...                            ...
# 50853                               119,190                         69,791
# 50854                                18,137                         21,833
# 50855                                16,951                         15,855
# 50856                                48,526                         71,955
# 50857                               111,631                         93,042
#
#       Some college (1-3 years), 1970 Four years of college or higher, 1970  \
# 0                                951                                   627
# 1                             87,675                                86,038
# 2                              2,206                                 1,441
# 3                             30,997                                21,697
# 4                             76,788                                65,504
# ...                              ...                                   ...
# 50853                         24,065                                29,291
# 50854                         11,460                                 8,122
# 50855                          8,193                                 5,254
# 50856                         39,161                                69,293
# 50857                         42,367                                37,278
#
#        Percent of adults with less than a high school diploma, 1970  \
# 0                                                   43.3
# 1                                                   37.0
# 2                                                   49.4
# 3                                                   47.3
# 4                                                   39.9
# ...                                                  ...
# 50853                                               49.2
# 50854                                               30.5
# 50855                                               36.6
# 50856                                               21.2
# 50857                                               39.3
#
#        Percent of adults with a high school diploma only, 1970  \
# 0                                                   38.4
# 1                                                   33.5
# 2                                                   35.9
# 3                                                   28.0
# 4                                                   32.2
# ...                                                  ...
# 50853                                               28.8
# 50854                                               36.7
# 50855                                               34.3
# 50856                                               31.4
# 50857                                               32.7
#
#        Percent of adults completing some college (1-3 years), 1970  \
# 0                                                   11.0
# 1                                                   14.9
# 2                                                    8.9
# 3                                                   14.5
# 4                                                   15.0
# ...                                                  ...
# 50853                                                9.9
# 50854                                               19.2
# 50855                                               17.7
# 50856                                               17.1
# 50857                                               14.9
#
#        Percent of adults completing four years of college or higher, 1970  \
# 0                                                    7.3
# 1                                                   14.6
# 2                                                    5.8
# 3                                                   10.2
# 4                                                   12.8
# ...                                                  ...
# 50853                                               12.1
# 50854                                               13.6
# 50855                                               11.4
# 50856                                               30.3
# 50857                                               13.1
#
#       Less than a high school diploma, 1980 High school diploma only, 1980  \
# 0                                     2,750                          3,719
# 1                                   162,536                        215,093
# 2                                     8,784                         10,639
# 3                                   104,714                         82,455
# 4                                   220,040                        307,465
# ...                                     ...                            ...
# 50853                                97,086                         90,512
# 50854                                17,805                         33,351
# 50855                                15,542                         21,539
# 50856                                40,983                         92,825
# 50857                                87,996                        116,547
#
#       Some college (1-3 years), 1980 Four years of college or higher, 1980  \
# 0                              1,290                                   827
# 1                            148,837                               151,045
# 2                              3,186                                 2,487
# 3                             57,896                                43,785
# 4                            192,183                               161,232
# ...                              ...                                   ...
# 50853                         42,938                                55,675
# 50854                         24,528                                21,475
# 50855                         14,834                                11,210
# 50856                         73,649                               148,863
# 50857                         66,027                                64,125
#
#        Percent of adults with less than a high school diploma, 1980  \
# 0                                                   32.0
# 1                                                   24.0
# 2                                                   35.0
# 3                                                   36.3
# 4                                                   25.0
# ...                                                  ...
# 50853                                               33.9
# 50854                                               18.3
# 50855                                               24.6
# 50856                                               11.5
# 50857                                               26.3
#
#        Percent of adults with a high school diploma only, 1980  \
# 0                                                   43.3
# 1                                                   31.7
# 2                                                   42.4
# 3                                                   28.5
# 4                                                   34.9
# ...                                                  ...
# 50853                                               31.6
# 50854                                               34.3
# 50855                                               34.1
# 50856                                               26.1
# 50857                                               34.8
#
#        Percent of adults completing some college (1-3 years), 1980  \
# 0                                                   15.0
# 1                                                   22.0
# 2                                                   12.7
# 3                                                   20.0
# 4                                                   21.8
# ...                                                  ...
# 50853                                               15.0
# 50854                                               25.2
# 50855                                               23.5
# 50856                                               20.7
# 50857                                               19.7
#
#        Percent of adults completing four years of college or higher, 1980  \
# 0                                                    9.6
# 1                                                   22.3
# 2                                                    9.9
# 3                                                   15.2
# 4                                                   18.3
# ...                                                  ...
# 50853                                               19.5
# 50854                                               22.1
# 50855                                               17.8
# 50856                                               41.8
# 50857                                               19.2
#
#       Less than a high school diploma, 1990 High school diploma only, 1990  \
# 0                                     1,694                          3,459
# 1                                   155,606                        190,822
# 2                                     6,197                          9,652
# 3                                   130,252                         83,536
# 4                                   248,814                        342,255
# ...                                     ...                            ...
# 50853                                81,073                         90,234
# 50854                                16,301                         33,194
# 50855                                14,495                         18,399
# 50856                                46,562                         91,675
# 50857                                80,030                         99,757
#
#       Some college or associate's degree, 1990 Bachelor's degree or higher, 1990  \
# 0                                        1,952                               932
# 1                                      250,389                           241,487
# 2                                        5,544                             2,633
# 3                                      106,640                            65,308
# 4                                      456,012                           297,573
# ...                                        ...                               ...
# 50853                                   82,646                            81,852
# 50854                                   46,313                            31,780
# 50855                                   25,538                            16,773
# 50856                                  137,320                           264,673
# 50857                                  116,426                            86,492
#
#        Percent of adults with less than a high school diploma, 1990  \
# 0                                                   21.1
# 1                                                   18.6
# 2                                                   25.8
# 3                                                   33.8
# 4                                                   18.5
# ...                                                  ...
# 50853                                               24.1
# 50854                                               12.8
# 50855                                               19.3
# 50856                                                8.6
# 50857                                               20.9
#
#        Percent of adults with a high school diploma only, 1990  \
# 0                                                   43.0
# 1                                                   22.8
# 2                                                   40.2
# 3                                                   21.7
# 4                                                   25.5
# ...                                                  ...
# 50853                                               26.9
# 50854                                               26.0
# 50855                                               24.5
# 50856                                               17.0
# 50857                                               26.1
#
#        Percent of adults completing some college or associate's degree, 1990  \
# 0                                                   24.3
# 1                                                   29.9
# 2                                                   23.1
# 3                                                   27.6
# 4                                                   33.9
# ...                                                  ...
# 50853                                               24.6
# 50854                                               36.3
# 50855                                               34.0
# 50856                                               25.4
# 50857                                               30.4
#
#        Percent of adults with a bachelor's degree or higher, 1990  \
# 0                                                   11.6
# 1                                                   28.8
# 2                                                   11.0
# 3                                                   16.9
# 4                                                   22.1
# ...                                                  ...
# 50853                                               24.4
# 50854                                               24.9
# 50855                                               22.3
# 50856                                               49.0
# 50857                                               22.6
#
#       Less than a high school diploma, 2000 High school diploma only, 2000  \
# 0                                     1,149                          3,002
# 1                                   168,281                        181,668
# 2                                     4,462                          9,616
# 3                                   147,937                         96,097
# 4                                   338,591                        446,445
# ...                                     ...                            ...
# 50853                                69,801                         93,105
# 50854                                17,377                         43,535
# 50855                                16,455                         17,223
# 50856                                60,477                         90,642
# 50857                                73,548                        109,475
#
#       Some college or associate's degree, 2000 Bachelor's degree or higher, 2000  \
# 0                                        2,514                             1,212
# 1                                      270,813                           332,954
# 2                                        6,529                             3,513
# 3                                      131,579                            79,927
# 4                                      649,040                           500,881
# ...                                        ...                               ...
# 50853                                   99,683                           115,145
# 50854                                   68,930                            58,820
# 50855                                   28,110                            22,150
# 50856                                  144,257                           357,861
# 50857                                  131,022                           106,778
#
#        Percent of adults with less than a high school diploma, 2000  \
# 0                                                   14.6
# 1                                                   17.6
# 2                                                   18.5
# 3                                                   32.5
# 4                                                   17.5
# ...                                                  ...
# 50853                                               18.5
# 50854                                                9.2
# 50855                                               19.6
# 50856                                                9.3
# 50857                                               17.5
#
#        Percent of adults with a high school diploma only, 2000  \
# 0                                                   38.1
# 1                                                   19.0
# 2                                                   39.9
# 3                                                   21.1
# 4                                                   23.1
# ...                                                  ...
# 50853                                               24.6
# 50854                                               23.1
# 50855                                               20.5
# 50856                                               13.9
# 50857                                               26.0
#
#        Percent of adults completing some college or associate's degree, 2000  \
# 0                                                   31.9
# 1                                                   28.4
# 2                                                   27.1
# 3                                                   28.9
# 4                                                   33.5
# ...                                                  ...
# 50853                                               26.4
# 50854                                               36.5
# 50855                                               33.5
# 50856                                               22.1
# 50857                                               31.1
#
#        Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                                   15.4
# 1                                                   34.9
# 2                                                   14.6
# 3                                                   17.5
# 4                                                   25.9
# ...                                                  ...
# 50853                                               30.5
# 50854                                               31.2
# 50855                                               26.4
# 50856                                               54.8
# 50857                                               25.4
#
#       Less than a high school diploma, 2008-12 High school diploma only, 2008-12  \
# 0                                          630                             2,756
# 1                                      141,402                           199,632
# 2                                        3,906                             8,924
# 3                                      148,450                           123,605
# 4                                      339,453                           568,115
# ...                                        ...                               ...
# 50853                                   59,351                           103,024
# 50854                                   17,187                            55,412
# 50855                                   16,172                            17,980
# 50856                                   61,889                            98,316
# 50857                                   65,386                           118,260
#
#       Some college or associate's degree, 2008-12 Bachelor's degree or higher, 2008-12  \
# 0                                           2,509                                1,388
# 1                                         262,546                              421,610
# 2                                           7,414                                3,691
# 3                                         167,607                              105,942
# 4                                         821,351                              722,479
# ...                                           ...                                  ...
# 50853                                     110,461                              146,971
# 50854                                      92,529                               90,216
# 50855                                      29,801                               29,034
# 50856                                     148,081                              429,065
# 50857                                     144,655                              136,279
#
#        Percent of adults with less than a high school diploma, 2008-12  \
# 0                                                    8.7
# 1                                                   13.8
# 2                                                   16.3
# 3                                                   27.2
# 4                                                   13.8
# ...                                                  ...
# 50853                                               14.1
# 50854                                                6.7
# 50855                                               17.4
# 50856                                                8.4
# 50857                                               14.1
#
#        Percent of adults with a high school diploma only, 2008-12  \
# 0                                                   37.8
# 1                                                   19.5
# 2                                                   37.3
# 3                                                   22.7
# 4                                                   23.2
# ...                                                  ...
# 50853                                               24.5
# 50854                                               21.7
# 50855                                               19.3
# 50856                                               13.3
# 50857                                               25.5
#
#        Percent of adults completing some college or associate's degree, 2008-12  \
# 0                                                   34.5
# 1                                                   25.6
# 2                                                   31.0
# 3                                                   30.7
# 4                                                   33.5
# ...                                                  ...
# 50853                                               26.3
# 50854                                               36.2
# 50855                                               32.0
# 50856                                               20.1
# 50857                                               31.1
#
#        Percent of adults with a bachelor's degree or higher, 2008-12  \
# 0                                                   19.1
# 1                                                   41.1
# 2                                                   15.4
# 3                                                   19.4
# 4                                                   29.5
# ...                                                  ...
# 50853                                               35.0
# 50854                                               35.3
# 50855                                               31.2
# 50856                                               58.2
# 50857                                               29.3
#
#       Less than a high school diploma, 2017-21 High school diploma only, 2017-21  \
# 0                                          423                             2,695
# 1                                      131,272                           198,825
# 2                                        2,885                             8,786
# 3                                      136,835                           140,532
# 4                                      326,737                           644,940
# ...                                        ...                               ...
# 50853                                   48,693                           104,797
# 50854                                   16,433                            68,936
# 50855                                   14,541                            17,698
# 50856                                   51,874                            96,148
# 50857                                   59,864                           127,327
#
#       Some college or associate's degree, 2017-21 Bachelor's degree or higher, 2017-21  \
# 0                                           2,458                                1,477
# 1                                         271,096                              592,670
# 2                                           7,765                                4,586
# 3                                         201,826                              140,183
# 4                                         950,635                            1,006,096
# ...                                           ...                                  ...
# 50853                                     120,227                              218,762
# 50854                                     110,566                              134,694
# 50855                                      29,842                               36,464
# 50856                                     137,108                              496,667
# 50857                                     155,471                              174,202
#
#        Percent of adults with less than a high school diploma, 2017-21  \
# 0                                                    6.0
# 1                                                   11.0
# 2                                                   12.0
# 3                                                   22.1
# 4                                                   11.2
# ...                                                  ...
# 50853                                                9.9
# 50854                                                5.0
# 50855                                               14.8
# 50856                                                6.6
# 50857                                               11.6
#
#        Percent of adults with a high school diploma only, 2017-21  \
# 0                                                   38.2
# 1                                                   16.7
# 2                                                   36.6
# 3                                                   22.7
# 4                                                   22.0
# ...                                                  ...
# 50853                                               21.3
# 50854                                               20.8
# 50855                                               18.0
# 50856                                               12.3
# 50857                                               24.6
#
#        Percent of adults completing some college or associate's degree, 2017-21  \
# 0                                                   34.9
# 1                                                   22.7
# 2                                                   32.3
# 3                                                   32.6
# 4                                                   32.5
# ...                                                  ...
# 50853                                               24.4
# 50854                                               33.4
# 50855                                               30.3
# 50856                                               17.5
# 50857                                               30.1
#
#        Percent of adults with a bachelor's degree or higher, 2017-21   fips
# 0                                                   20.9              19025
# 1                                                   49.6               6001
# 2                                                   19.1              19179
# 3                                                   22.6               6019
# 4                                                   34.4               4013
# ...                                                  ...                ...
# 50853                                               44.4              47037
# 50854                                               40.7              16001
# 50855                                               37.0               6055
# 50856                                               63.5              51059
# 50857                                               33.7              40109
#
# [49610 rows x 71 columns]

# %% [markdown]
# # Normalize number of sightings by county population with non census data

# %% [markdown]
# Source:https://www.ers.usda.gov/data-products/county-level-data-sets/county-level-data-sets-download-data/

# %%
url = 'https://raw.githubusercontent.com/maxsohl/GSB521FinalProj/main/PopulationEstimates.csv'
pop_df = pd.read_csv(url)
pop_df
# Out:
#        fips state               county  Rural-Urban Continuum Code 2013 Population 1990  \
# 0         0    US        United States                              NaN     248,790,925
# 1      1000    AL              Alabama                              NaN       4,040,389
# 2      1001    AL       Autauga County                              2.0          34,222
# 3      1003    AL       Baldwin County                              3.0          98,280
# 4      1005    AL       Barbour County                              6.0          25,417
# ...     ...   ...                  ...                              ...             ...
# 3275  72145    PR  Vega Baja Municipio                              1.0          55,997
# 3276  72147    PR    Vieques Municipio                              7.0           8,602
# 3277  72149    PR   Villalba Municipio                              2.0          23,559
# 3278  72151    PR    Yabucoa Municipio                              1.0          36,483
# 3279  72153    PR      Yauco Municipio                              2.0          42,058
#
#      Population 2000 Population 2010 Population 2020 Population 2021
# 0        281,424,600     308,745,538     331,449,281     331,893,745
# 1          4,447,207       4,779,736       5,024,279       5,039,877
# 2             43,751          54,571          58,805          59,095
# 3            140,416         182,265         231,767         239,294
# 4             29,042          27,457          25,223          24,964
# ...              ...             ...             ...             ...
# 3275          61,916          59,662          54,414          53,897
# 3276           9,106           9,301           8,249           8,224
# 3277          27,910          26,073          22,093          21,813
# 3278          39,121          37,941          30,426          30,186
# 3279          46,398          42,043          34,172          33,633
#
# [3280 rows x 9 columns]

# %%
print(pop_df.dtypes)
# Out:
# fips                                 int64
# state                               object
# county                              object
# Rural-Urban Continuum Code 2013    float64
# Population 1990                     object
# Population 2000                     object
# Population 2010                     object
# Population 2020                     object
# Population 2021                     object
# dtype: object

# %%
print(education_merged_df_fips.dtypes)
# Out:
# datetime                                                                    datetime64[ns]
# city                                                                                object
# state                                                                               object
# country                                                                             object
# shape                                                                               object
#                                                                                  ...
# Percent of adults with less than a high school diploma, 2017-21                    float64
# Percent of adults with a high school diploma only, 2017-21                         float64
# Percent of adults completing some college or associate's degree, 2017-21           float64
# Percent of adults with a bachelor's degree or higher, 2017-21                      float64
# fips                                                                                 int64
# Length: 71, dtype: object

# %%
pop_educ_alien_df = pd.merge(education_merged_df_fips, pop_df, on='fips', how='left')
pop_educ_alien_df
# Out:
#                  datetime           city state_x country      shape duration (seconds)  \
# 0     2001-10-10 03:00:00  rockwell city      ia      us   triangle                240
# 1     2001-10-10 20:35:00        hayward      ca      us     circle                120
# 2     2001-10-10 21:15:00        ottumwa      ia      us  rectangle                300
# 3     2001-10-10 21:30:00         fresno      ca      us   changing                900
# 4     2001-10-10 22:00:00        phoenix      az      us   triangle                 60
# ...                   ...            ...     ...     ...        ...                ...
# 49605 2013-09-09 21:15:00      nashville      tn      us      light              600.0
# 49606 2013-09-09 22:00:00          boise      id      us     circle             1200.0
# 49607 2013-09-09 22:00:00           napa      ca      us      other             1200.0
# 49608 2013-09-09 22:20:00         vienna      va      us     circle                5.0
# 49609 2013-09-09 23:00:00         edmond      ok      us      cigar             1020.0
#
#       duration (hours/min)                                           comments date posted  \
# 0                  4 min.s  Large&#44silent&#44slow&#44low to the ground d...  2002-07-01
# 1                   2/min.  FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...  2001-11-20
# 2              3-5 minutes  We saw a square object at night&#44  which had...  2001-11-20
# 3            15 min. apprx  Objects were sighted driving north on Highway ...  2001-11-20
# 4       less then a minute  Triangle shaped craft spotted flying west to e...  2001-11-20
# ...                    ...                                                ...         ...
# 49605           10 minutes  Round from the distance/slowly changing colors...  2013-09-30
# 49606           20 minutes  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 49607                 hour                                       Napa UFO&#44  2013-09-30
# 49608            5 seconds  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 49609           17 minutes  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#          latitude  longitude         date      time  year         county_x  \
# 0      42.3952778  -94.633611  2001-10-10  03:00:00  2001   calhoun county
# 1      37.6688889 -122.079722  2001-10-10  20:35:00  2001   alameda county
# 2      41.0041667  -92.373611  2001-10-10  21:15:00  2001   wapello county
# 3      36.7477778 -119.771389  2001-10-10  21:30:00  2001    fresno county
# 4      33.4483333 -112.073333  2001-10-10  22:00:00  2001  maricopa county
# ...           ...         ...         ...       ...   ...              ...
# 49605   36.165833  -86.784444  2013-09-09  21:15:00  2013  davidson county
# 49606   43.613611 -116.202500  2013-09-09  22:00:00  2013       ada county
# 49607   38.297222 -122.284444  2013-09-09  22:00:00  2013      napa county
# 49608   38.901111  -77.265556  2013-09-09  22:20:00  2013   fairfax county
# 49609   35.652778  -97.477778  2013-09-09  23:00:00  2013  oklahoma county
#
#        Federal Information Processing Standard (FIPS) Code State        Area name  \
# 0                                                19025.0      IA   Calhoun County
# 1                                                 6001.0      CA   Alameda County
# 2                                                19179.0      IA   Wapello County
# 3                                                 6019.0      CA    Fresno County
# 4                                                 4013.0      AZ  Maricopa County
# ...                                                  ...     ...              ...
# 49605                                            47037.0      TN  Davidson County
# 49606                                            16001.0      ID       Ada County
# 49607                                             6055.0      CA      Napa County
# 49608                                            51059.0      VA   Fairfax County
# 49609                                            40109.0      OK  Oklahoma County
#
#        2003 Rural-urban Continuum Code  2003 Urban Influence Code  \
# 0                                  9.0                       10.0
# 1                                  1.0                        1.0
# 2                                  5.0                        8.0
# 3                                  2.0                        2.0
# 4                                  1.0                        1.0
# ...                                ...                        ...
# 49605                              1.0                        1.0
# 49606                              2.0                        2.0
# 49607                              3.0                        2.0
# 49608                              1.0                        1.0
# 49609                              1.0                        1.0
#
#        2013 Rural-urban Continuum Code  2013 Urban Influence Code  \
# 0                                  9.0                       10.0
# 1                                  1.0                        1.0
# 2                                  5.0                        8.0
# 3                                  2.0                        2.0
# 4                                  1.0                        1.0
# ...                                ...                        ...
# 49605                              1.0                        1.0
# 49606                              2.0                        2.0
# 49607                              3.0                        2.0
# 49608                              1.0                        1.0
# 49609                              1.0                        1.0
#
#       Less than a high school diploma, 1970 High school diploma only, 1970  \
# 0                                     3,740                          3,319
# 1                                   217,589                        197,371
# 2                                    12,247                          8,893
# 3                                   100,900                         59,798
# 4                                   203,922                        164,605
# ...                                     ...                            ...
# 49605                               119,190                         69,791
# 49606                                18,137                         21,833
# 49607                                16,951                         15,855
# 49608                                48,526                         71,955
# 49609                               111,631                         93,042
#
#       Some college (1-3 years), 1970 Four years of college or higher, 1970  \
# 0                                951                                   627
# 1                             87,675                                86,038
# 2                              2,206                                 1,441
# 3                             30,997                                21,697
# 4                             76,788                                65,504
# ...                              ...                                   ...
# 49605                         24,065                                29,291
# 49606                         11,460                                 8,122
# 49607                          8,193                                 5,254
# 49608                         39,161                                69,293
# 49609                         42,367                                37,278
#
#        Percent of adults with less than a high school diploma, 1970  \
# 0                                                   43.3
# 1                                                   37.0
# 2                                                   49.4
# 3                                                   47.3
# 4                                                   39.9
# ...                                                  ...
# 49605                                               49.2
# 49606                                               30.5
# 49607                                               36.6
# 49608                                               21.2
# 49609                                               39.3
#
#        Percent of adults with a high school diploma only, 1970  \
# 0                                                   38.4
# 1                                                   33.5
# 2                                                   35.9
# 3                                                   28.0
# 4                                                   32.2
# ...                                                  ...
# 49605                                               28.8
# 49606                                               36.7
# 49607                                               34.3
# 49608                                               31.4
# 49609                                               32.7
#
#        Percent of adults completing some college (1-3 years), 1970  \
# 0                                                   11.0
# 1                                                   14.9
# 2                                                    8.9
# 3                                                   14.5
# 4                                                   15.0
# ...                                                  ...
# 49605                                                9.9
# 49606                                               19.2
# 49607                                               17.7
# 49608                                               17.1
# 49609                                               14.9
#
#        Percent of adults completing four years of college or higher, 1970  \
# 0                                                    7.3
# 1                                                   14.6
# 2                                                    5.8
# 3                                                   10.2
# 4                                                   12.8
# ...                                                  ...
# 49605                                               12.1
# 49606                                               13.6
# 49607                                               11.4
# 49608                                               30.3
# 49609                                               13.1
#
#       Less than a high school diploma, 1980 High school diploma only, 1980  \
# 0                                     2,750                          3,719
# 1                                   162,536                        215,093
# 2                                     8,784                         10,639
# 3                                   104,714                         82,455
# 4                                   220,040                        307,465
# ...                                     ...                            ...
# 49605                                97,086                         90,512
# 49606                                17,805                         33,351
# 49607                                15,542                         21,539
# 49608                                40,983                         92,825
# 49609                                87,996                        116,547
#
#       Some college (1-3 years), 1980 Four years of college or higher, 1980  \
# 0                              1,290                                   827
# 1                            148,837                               151,045
# 2                              3,186                                 2,487
# 3                             57,896                                43,785
# 4                            192,183                               161,232
# ...                              ...                                   ...
# 49605                         42,938                                55,675
# 49606                         24,528                                21,475
# 49607                         14,834                                11,210
# 49608                         73,649                               148,863
# 49609                         66,027                                64,125
#
#        Percent of adults with less than a high school diploma, 1980  \
# 0                                                   32.0
# 1                                                   24.0
# 2                                                   35.0
# 3                                                   36.3
# 4                                                   25.0
# ...                                                  ...
# 49605                                               33.9
# 49606                                               18.3
# 49607                                               24.6
# 49608                                               11.5
# 49609                                               26.3
#
#        Percent of adults with a high school diploma only, 1980  \
# 0                                                   43.3
# 1                                                   31.7
# 2                                                   42.4
# 3                                                   28.5
# 4                                                   34.9
# ...                                                  ...
# 49605                                               31.6
# 49606                                               34.3
# 49607                                               34.1
# 49608                                               26.1
# 49609                                               34.8
#
#        Percent of adults completing some college (1-3 years), 1980  \
# 0                                                   15.0
# 1                                                   22.0
# 2                                                   12.7
# 3                                                   20.0
# 4                                                   21.8
# ...                                                  ...
# 49605                                               15.0
# 49606                                               25.2
# 49607                                               23.5
# 49608                                               20.7
# 49609                                               19.7
#
#        Percent of adults completing four years of college or higher, 1980  \
# 0                                                    9.6
# 1                                                   22.3
# 2                                                    9.9
# 3                                                   15.2
# 4                                                   18.3
# ...                                                  ...
# 49605                                               19.5
# 49606                                               22.1
# 49607                                               17.8
# 49608                                               41.8
# 49609                                               19.2
#
#       Less than a high school diploma, 1990 High school diploma only, 1990  \
# 0                                     1,694                          3,459
# 1                                   155,606                        190,822
# 2                                     6,197                          9,652
# 3                                   130,252                         83,536
# 4                                   248,814                        342,255
# ...                                     ...                            ...
# 49605                                81,073                         90,234
# 49606                                16,301                         33,194
# 49607                                14,495                         18,399
# 49608                                46,562                         91,675
# 49609                                80,030                         99,757
#
#       Some college or associate's degree, 1990 Bachelor's degree or higher, 1990  \
# 0                                        1,952                               932
# 1                                      250,389                           241,487
# 2                                        5,544                             2,633
# 3                                      106,640                            65,308
# 4                                      456,012                           297,573
# ...                                        ...                               ...
# 49605                                   82,646                            81,852
# 49606                                   46,313                            31,780
# 49607                                   25,538                            16,773
# 49608                                  137,320                           264,673
# 49609                                  116,426                            86,492
#
#        Percent of adults with less than a high school diploma, 1990  \
# 0                                                   21.1
# 1                                                   18.6
# 2                                                   25.8
# 3                                                   33.8
# 4                                                   18.5
# ...                                                  ...
# 49605                                               24.1
# 49606                                               12.8
# 49607                                               19.3
# 49608                                                8.6
# 49609                                               20.9
#
#        Percent of adults with a high school diploma only, 1990  \
# 0                                                   43.0
# 1                                                   22.8
# 2                                                   40.2
# 3                                                   21.7
# 4                                                   25.5
# ...                                                  ...
# 49605                                               26.9
# 49606                                               26.0
# 49607                                               24.5
# 49608                                               17.0
# 49609                                               26.1
#
#        Percent of adults completing some college or associate's degree, 1990  \
# 0                                                   24.3
# 1                                                   29.9
# 2                                                   23.1
# 3                                                   27.6
# 4                                                   33.9
# ...                                                  ...
# 49605                                               24.6
# 49606                                               36.3
# 49607                                               34.0
# 49608                                               25.4
# 49609                                               30.4
#
#        Percent of adults with a bachelor's degree or higher, 1990  \
# 0                                                   11.6
# 1                                                   28.8
# 2                                                   11.0
# 3                                                   16.9
# 4                                                   22.1
# ...                                                  ...
# 49605                                               24.4
# 49606                                               24.9
# 49607                                               22.3
# 49608                                               49.0
# 49609                                               22.6
#
#       Less than a high school diploma, 2000 High school diploma only, 2000  \
# 0                                     1,149                          3,002
# 1                                   168,281                        181,668
# 2                                     4,462                          9,616
# 3                                   147,937                         96,097
# 4                                   338,591                        446,445
# ...                                     ...                            ...
# 49605                                69,801                         93,105
# 49606                                17,377                         43,535
# 49607                                16,455                         17,223
# 49608                                60,477                         90,642
# 49609                                73,548                        109,475
#
#       Some college or associate's degree, 2000 Bachelor's degree or higher, 2000  \
# 0                                        2,514                             1,212
# 1                                      270,813                           332,954
# 2                                        6,529                             3,513
# 3                                      131,579                            79,927
# 4                                      649,040                           500,881
# ...                                        ...                               ...
# 49605                                   99,683                           115,145
# 49606                                   68,930                            58,820
# 49607                                   28,110                            22,150
# 49608                                  144,257                           357,861
# 49609                                  131,022                           106,778
#
#        Percent of adults with less than a high school diploma, 2000  \
# 0                                                   14.6
# 1                                                   17.6
# 2                                                   18.5
# 3                                                   32.5
# 4                                                   17.5
# ...                                                  ...
# 49605                                               18.5
# 49606                                                9.2
# 49607                                               19.6
# 49608                                                9.3
# 49609                                               17.5
#
#        Percent of adults with a high school diploma only, 2000  \
# 0                                                   38.1
# 1                                                   19.0
# 2                                                   39.9
# 3                                                   21.1
# 4                                                   23.1
# ...                                                  ...
# 49605                                               24.6
# 49606                                               23.1
# 49607                                               20.5
# 49608                                               13.9
# 49609                                               26.0
#
#        Percent of adults completing some college or associate's degree, 2000  \
# 0                                                   31.9
# 1                                                   28.4
# 2                                                   27.1
# 3                                                   28.9
# 4                                                   33.5
# ...                                                  ...
# 49605                                               26.4
# 49606                                               36.5
# 49607                                               33.5
# 49608                                               22.1
# 49609                                               31.1
#
#        Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                                   15.4
# 1                                                   34.9
# 2                                                   14.6
# 3                                                   17.5
# 4                                                   25.9
# ...                                                  ...
# 49605                                               30.5
# 49606                                               31.2
# 49607                                               26.4
# 49608                                               54.8
# 49609                                               25.4
#
#       Less than a high school diploma, 2008-12 High school diploma only, 2008-12  \
# 0                                          630                             2,756
# 1                                      141,402                           199,632
# 2                                        3,906                             8,924
# 3                                      148,450                           123,605
# 4                                      339,453                           568,115
# ...                                        ...                               ...
# 49605                                   59,351                           103,024
# 49606                                   17,187                            55,412
# 49607                                   16,172                            17,980
# 49608                                   61,889                            98,316
# 49609                                   65,386                           118,260
#
#       Some college or associate's degree, 2008-12 Bachelor's degree or higher, 2008-12  \
# 0                                           2,509                                1,388
# 1                                         262,546                              421,610
# 2                                           7,414                                3,691
# 3                                         167,607                              105,942
# 4                                         821,351                              722,479
# ...                                           ...                                  ...
# 49605                                     110,461                              146,971
# 49606                                      92,529                               90,216
# 49607                                      29,801                               29,034
# 49608                                     148,081                              429,065
# 49609                                     144,655                              136,279
#
#        Percent of adults with less than a high school diploma, 2008-12  \
# 0                                                    8.7
# 1                                                   13.8
# 2                                                   16.3
# 3                                                   27.2
# 4                                                   13.8
# ...                                                  ...
# 49605                                               14.1
# 49606                                                6.7
# 49607                                               17.4
# 49608                                                8.4
# 49609                                               14.1
#
#        Percent of adults with a high school diploma only, 2008-12  \
# 0                                                   37.8
# 1                                                   19.5
# 2                                                   37.3
# 3                                                   22.7
# 4                                                   23.2
# ...                                                  ...
# 49605                                               24.5
# 49606                                               21.7
# 49607                                               19.3
# 49608                                               13.3
# 49609                                               25.5
#
#        Percent of adults completing some college or associate's degree, 2008-12  \
# 0                                                   34.5
# 1                                                   25.6
# 2                                                   31.0
# 3                                                   30.7
# 4                                                   33.5
# ...                                                  ...
# 49605                                               26.3
# 49606                                               36.2
# 49607                                               32.0
# 49608                                               20.1
# 49609                                               31.1
#
#        Percent of adults with a bachelor's degree or higher, 2008-12  \
# 0                                                   19.1
# 1                                                   41.1
# 2                                                   15.4
# 3                                                   19.4
# 4                                                   29.5
# ...                                                  ...
# 49605                                               35.0
# 49606                                               35.3
# 49607                                               31.2
# 49608                                               58.2
# 49609                                               29.3
#
#       Less than a high school diploma, 2017-21 High school diploma only, 2017-21  \
# 0                                          423                             2,695
# 1                                      131,272                           198,825
# 2                                        2,885                             8,786
# 3                                      136,835                           140,532
# 4                                      326,737                           644,940
# ...                                        ...                               ...
# 49605                                   48,693                           104,797
# 49606                                   16,433                            68,936
# 49607                                   14,541                            17,698
# 49608                                   51,874                            96,148
# 49609                                   59,864                           127,327
#
#       Some college or associate's degree, 2017-21 Bachelor's degree or higher, 2017-21  \
# 0                                           2,458                                1,477
# 1                                         271,096                              592,670
# 2                                           7,765                                4,586
# 3                                         201,826                              140,183
# 4                                         950,635                            1,006,096
# ...                                           ...                                  ...
# 49605                                     120,227                              218,762
# 49606                                     110,566                              134,694
# 49607                                      29,842                               36,464
# 49608                                     137,108                              496,667
# 49609                                     155,471                              174,202
#
#        Percent of adults with less than a high school diploma, 2017-21  \
# 0                                                    6.0
# 1                                                   11.0
# 2                                                   12.0
# 3                                                   22.1
# 4                                                   11.2
# ...                                                  ...
# 49605                                                9.9
# 49606                                                5.0
# 49607                                               14.8
# 49608                                                6.6
# 49609                                               11.6
#
#        Percent of adults with a high school diploma only, 2017-21  \
# 0                                                   38.2
# 1                                                   16.7
# 2                                                   36.6
# 3                                                   22.7
# 4                                                   22.0
# ...                                                  ...
# 49605                                               21.3
# 49606                                               20.8
# 49607                                               18.0
# 49608                                               12.3
# 49609                                               24.6
#
#        Percent of adults completing some college or associate's degree, 2017-21  \
# 0                                                   34.9
# 1                                                   22.7
# 2                                                   32.3
# 3                                                   32.6
# 4                                                   32.5
# ...                                                  ...
# 49605                                               24.4
# 49606                                               33.4
# 49607                                               30.3
# 49608                                               17.5
# 49609                                               30.1
#
#        Percent of adults with a bachelor's degree or higher, 2017-21   fips state_y  \
# 0                                                   20.9              19025      IA
# 1                                                   49.6               6001      CA
# 2                                                   19.1              19179      IA
# 3                                                   22.6               6019      CA
# 4                                                   34.4               4013      AZ
# ...                                                  ...                ...     ...
# 49605                                               44.4              47037      TN
# 49606                                               40.7              16001      ID
# 49607                                               37.0               6055      CA
# 49608                                               63.5              51059      VA
# 49609                                               33.7              40109      OK
#
#               county_y  Rural-Urban Continuum Code 2013 Population 1990 Population 2000  \
# 0       Calhoun County                              9.0          11,508          11,114
# 1       Alameda County                              1.0       1,304,347       1,443,705
# 2       Wapello County                              5.0          35,696          36,067
# 3        Fresno County                              2.0         667,479         798,766
# 4      Maricopa County                              1.0       2,122,101       3,072,415
# ...                ...                              ...             ...             ...
# 49605  Davidson County                              1.0         510,786         569,927
# 49606       Ada County                              2.0         205,775         300,953
# 49607      Napa County                              3.0         110,765         124,344
# 49608   Fairfax County                              1.0         818,310         969,987
# 49609  Oklahoma County                              1.0         599,611         660,581
#
#       Population 2010 Population 2020 Population 2021
# 0               9,670           9,927           9,915
# 1           1,510,271       1,682,353       1,648,556
# 2              35,625          35,437          35,256
# 3             930,450       1,008,654       1,013,581
# 4           3,817,117       4,420,568       4,496,588
# ...               ...             ...             ...
# 49605         626,681         715,884         703,953
# 49606         392,365         494,967         511,931
# 49607         136,484         138,019         136,207
# 49608       1,081,726       1,150,309       1,139,720
# 49609         718,633         796,292         798,575
#
# [49610 rows x 79 columns]

# %%
county_count_df = pop_educ_alien_df.groupby(['fips']).size().reset_index(name='count')
county_count_df
county_count_merged_df = pd.merge(county_count_df, pop_educ_alien_df[['fips', 'latitude', 'longitude ']], on=['fips'], how='left')
county_count_merged_df
#county_count_merged_df = county_count_merged_df.drop_duplicates(subset=['county'])
#county_count_merged_df
# Out:
#         fips  count    latitude  longitude
# 0       1001      4  32.4638889  -86.459722
# 1       1001      4  32.4638889  -86.459722
# 2       1001      4  32.4638889  -86.459722
# 3       1001      4  32.4638889  -86.459722
# 4       1003     40  30.2458333  -87.700833
# ...      ...    ...         ...         ...
# 49605  56041      7  41.2683333 -110.962500
# 49606  56041      7  41.2683333 -110.962500
# 49607  56041      7   41.316667 -110.383611
# 49608  56043      2  44.0169444 -107.954722
# 49609  56043      2  44.0169444 -107.954722
#
# [49610 rows x 4 columns]

# %% [markdown]
# # Geo heatmap of number of sightings in each county

# %%
county_count_df = education_merged_df.groupby(['state', 'county']).size().reset_index(name='count')
county_count_merged_df = pd.merge(county_count_df, education_merged_df[['county', 'state', 'latitude', 'longitude ']], on=['county', 'state'], how='left')
county_count_merged_df = county_count_merged_df.drop_duplicates(subset=['county'])
county_count_merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ks/cjwkk0rj61b1r0vb8md0w0x80000gn/T/ipykernel_58322/228435330.py in <module>
#       1 county_count_df = pop_educ_alien_df.groupby('fips').size().reset_index(name='count')
# ----> 2 county_count_merged_df = pd.merge(county_count_df, pop_educ_alien_df[['county', 'state', 'latitude', 'longitude ']], on=['fips'], how='left')
#       3 county_count_merged_df = county_count_merged_df.drop_duplicates(subset=['county'])
#       4 county_count_merged_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859             raise KeyError(f"{not_found} not in index")
#    5860
#    5861     @overload
#
# KeyError: "['county', 'state'] not in index"

# %%
#Still need to change the colors, scope, normalize pop, etc
map = folium.Map(location=[37,-96], zoom_start=4)
heatmap = HeatMap(county_count_merged_df[['latitude', 'longitude ', 'count']].values.tolist(), radius=10, max_val=50)
heatmap.add_to(map)
map

# %% [markdown]
# Prof reccomended https://nbviewer.org/ to show interactive notebooks
